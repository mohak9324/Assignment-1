# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
#Q1

# %% [markdown]
# Matplotlib is a popular data visualization library in Python used to create static, interactive, and animated plots. It provides a wide range of plotting options and is extensively used in various fields like data analysis, scientific research, and data exploration.

# %% [markdown]
# Line Plot,Scatter Plot,Bar Plot,Histogram,Pie Chart

# %%
#Q2

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Scatter Plot")
plt.show()

# %%
#Q3

# %%
 x = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')
plt.show()

# %%
#Q4

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
#Q5

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc7d180a2f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc7d1808df0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc7d18102e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc7d180ace0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc7d180a8c0>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc7d1e83190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc7d1f0d330>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc7d1e82fe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc7d1f0d780>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc7d1f0d030>],
#  'means': []}

# %% [markdown]
# box plot is used to identify outliers in the data.
