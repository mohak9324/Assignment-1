# %%
#Q1

# %% [markdown]
# GET:- it is used to fetch data from server by passing parameter value , and the parameter value can be seen in the URL.
#
# POST:- it is used to fetch data by creating a form and passing all the values inside the form to a function and returns a value.

# %%
#Q2

# %% [markdown]
# Request is used to handle HTTP request made by client, request object is used to access data from a form submitted by client.
# Flask allows you to define dynamic routes with URL parameters. The request object helps you extract these parameters from the URL so that you can use them in your application logic.

# %%
#Q3

# %% [markdown]
# Redirect() is used to redirect url to different url.

# %%
#Q4

# %% [markdown]
# Templates are HTML  page where all the formating and forms are made,
# render_template() is used to render or pull that HTML page where client is submitting form or after submitting form the client should be directed to a particular page.

# %%
#Q5

# %%
from IPython.display import Image

Image(filename='postman.png')
