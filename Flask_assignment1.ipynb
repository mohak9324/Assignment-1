# %%
#Q1

# %% [markdown]
# Flask is a light framework written in python to design web applications.
# Flask follows M-V-C (model view Controller) architecture.
#
# Advantage:-
# 1. Simplicity :- simple design
# 2. Light weight:- does not requir any additional libraries to function.
# 3. flexible:- Flask gives developers the freedom to choose the components they want to use.

# %%
#Q2

# %%
from IPython.display import Image

Image(filename='Hello_world.png')

# %%
#Q3

# %% [markdown]
# app route means mapping url to a particular function or methode in code ,when running the particular url it will hit the particular method and will execute the methode.

# %%
#Q4

# %%
Image(filename='Welcome.png')

# %%
Image(filename='Company_details.png')

# %%
#Q5

# %% [raw]
# from flask import Flask,url_for
#
# app = Flask(__name__)
#
# # @app.route("/")
# # def hello_world():
# #     return "<h1>Hello, World!</h1>"
#
# @app.route("/welcome")
# def welcome_msg():
#     return "Welcome to ABC Corporation"
#
# @app.route("/a")
# def a_msg():
#     return '''
#     Company Name: ABC Corporation
#     Location: India
#     Contact Detail: 999-999-9999
#     '''
#
#
# @app.route('/')
# def home():
#     return 'Welcome to the Home Page!'
#
# @app.route('/about')
# def about():
#     return 'This is the About Page!'
#
# @app.route('/contact')
# def contact():
#     return 'You can contact us here!'
#
# @app.route('/user/<username>')
# def user_profile(username):
#     return f'This is the profile page for {username}'
#
# if __name__ == '__main__':
#     with app.test_request_context():
#         # Generate URLs using url_for()
#         home_url = url_for('home')
#         about_url = url_for('about')
#         contact_url = url_for('contact')
#         user_url = url_for('user_profile', username='John')
#
#         # Print the generated URLs
#         print("Home URL:", home_url)
#         print("About URL:", about_url)
#         print("Contact URL:", contact_url)
#         print("User Profile URL:", user_url)
#
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
